# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.shape[0]
# Out:
# 244

# %%
sns.histplot(df, x = "total_bill", bins=50)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# pengeluaran bill terbanyak diantara 10-20 us dollar

# %%
sns.scatterplot(df, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# banyaknya tip tergantung dengan banyaknya pengeluaran bill nya. Makin tinggi bill, makin tinggi tip nya dan juga sebaliknya

# %%
sns.boxplot(df, x="total_bill", y="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# banyaknya pengeluaran bill terjadi pada weekend.
